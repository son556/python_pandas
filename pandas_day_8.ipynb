# %%
# 데이터프레임의 행과 열을 바꿈 : 전치행렬
import pandas as pd

# %%
exam_data = {'이름': ['서준','우현','인아'],
            '수학':[90,80,70],
            '영어':[98,89,95],
            '국어':[98,89,95]}
df = pd.DataFrame(exam_data)
print(df)

# df.set_index(['국어','영어'], inplace = True)
df.set_index('이름', inplace = True)
print(df)
# Out:
#    이름  수학  영어  국어
# 0  서준  90  98  98
# 1  우현  80  89  89
# 2  인아  70  95  95
#     수학  영어  국어
# 이름
# 서준  90  98  98
# 우현  80  89  89
# 인아  70  95  95

# %%
df = df.T
print(df)
df
# Out:
# 이름  서준  우현  인아
# 수학  90  80  70
# 영어  98  89  95
# 국어  98  89  95
# 이름  서준  우현  인아
# 수학  90  80  70
# 영어  98  89  95
# 국어  98  89  95

# %%
# reindex(새로운 인덱스 배열) : 기존의 자료변경 안함, 새로운 데이터프레임 반환
dict_data = {'c0':[1,2,3],'c1':[4,5,6],'c2':[7,8,9],'c3':[10,11,12]}
df = pd.DataFrame(dict_data, index = ['r1','r2','r3'])
df
# Out:
#     c0  c1  c2  c3
# r1   1   4   7  10
# r2   2   5   8  11
# r3   3   6   9  12

# %%
# index를 ['r0','r1','r2','r3','r4']
new_index = ['r0','r1','r2','r3','r4']
ndf = df.reindex(new_index) # 존재하지 않는 인덱스의 값은 NaN
print(ndf)
# 존재하지 않는 인덱스의 값을 0으로 채워 줌
ndf1 = df.reindex(new_index, fill_value = 0)
ndf1
# method : ffill 이전자료 복사, bfill : 이후 자료 복사 -> NaN에 채움
ndf2 = df.reindex(new_index, method = 'ffill')
ndf2
# Out:
#      c0   c1   c2    c3
# r0  NaN  NaN  NaN   NaN
# r1  1.0  4.0  7.0  10.0
# r2  2.0  5.0  8.0  11.0
# r3  3.0  6.0  9.0  12.0
# r4  NaN  NaN  NaN   NaN
#      c0   c1   c2    c3
# r0  NaN  NaN  NaN   NaN
# r1  1.0  4.0  7.0  10.0
# r2  2.0  5.0  8.0  11.0
# r3  3.0  6.0  9.0  12.0
# r4  3.0  6.0  9.0  12.0

# %%
# reset_index() : 인덱스 초기화
print(df)
print(df.reset_index()) # 기존의 인덱스가 컬럼으로 변환, 인덱스는 초기화
df.reset_index(drop=True)# 기존의 인덱스를 삭제, 인덱스는 초기화
df
# Out:
#     c0  c1  c2  c3
# r1   1   4   7  10
# r2   2   5   8  11
# r3   3   6   9  12
#   index  c0  c1  c2  c3
# 0    r1   1   4   7  10
# 1    r2   2   5   8  11
# 2    r3   3   6   9  12
#     c0  c1  c2  c3
# r1   1   4   7  10
# r2   2   5   8  11
# r3   3   6   9  12

# %%
# 인덱스를 기준으로 정렬
df.sort_index(ascending=False) # ascending = True 로 설정되어 있음
# Out:
#     c0  c1  c2  c3
# r3   3   6   9  12
# r2   2   5   8  11
# r1   1   4   7  10

# %%
# 컬럼을 기준으로 정렬
df.loc['r1','c0'] = 2
df.loc['r2','c2'] = 15
df.sort_values(by = ['c0','c2'], ascending = False)
# Out:
#     c0  c1  c2  c3
# r3   3   6   9  12
# r2   2   5  15  11
# r1   2   4   7  10

# %%
# 인덱스를 설정 df.index = []
# 컬럼명을 설정 df.columns = []
# 인덱스의 이름을 변경 df.rename({기존인덱스:새로운인덱스,...},inplace=)
# 컬럼명을 변경 df.rename({기존컬럼:새로운컬럼,...},inplace =)
# 인덱스를 삭제 df.drop([인덱스명],axis = 0)
# 컬럼 삭제 df.drop([컬럼명],axis = 1)
# 새로운 인덱스 부여 : ndf = df.reindex(new_index,[fill_value= or mehtod=])
# 인덱스 제거 df.reset_index([drop=True])인덱스를 컬럼으로 변환하지 않음
# 인덱스 기준으로 정렬 df.sort_index([ascending = 1])
# 컬럼 기준으로 정렬 df.sort_values(by = [컬럼명])

# %%
# 시리즈 연산 : 시리즈 +,-,/,* 사칙연산 가능
# 1.인덱스로 정렬
# 2.매칭되는 값에 대한 연산, NaN 이 있으면 결과는 NaN
# 3.결과 리턴 -> 인덱스로 정렬된 상태

# %%
student = pd.Series({'국어':100,'수학':90,'영어':90})
print(student)

print(student+200)
print(student/200)
print(student-50)
# Out:
# 국어    100
# 수학     90
# 영어     90
# dtype: int64
# 국어    300
# 수학    290
# 영어    290
# dtype: int64
# 국어    0.50
# 수학    0.45
# 영어    0.45
# dtype: float64
# 국어    50
# 수학    40
# 영어    40
# dtype: int64

# %%
# 시리즈 연산
import numpy as np
student1 = pd.Series({'국어':np.nan,'수학':90,'영어':90})
student2 = pd.Series({'국어':100,'수학':90,'영어':90, '과학':100})
print(student1 + student2)
# Out:
# 과학      NaN
# 국어      NaN
# 수학    180.0
# 영어    180.0
# dtype: float64

# %%
# 시리즈 연산 메서드 : 시리즈.add(시리즈1,fill_value=)
print(student1.add(student2,fill_value = 0))# ->nan = 0
print(student1.sub(student2,fill_value = 0))
print(student1.mul(student2,fill_value = 0))
print(student1.div(student2,fill_value = 0))
# Out:
# 과학    100.0
# 국어    100.0
# 수학    180.0
# 영어    180.0
# dtype: float64
# 과학   -100.0
# 국어   -100.0
# 수학      0.0
# 영어      0.0
# dtype: float64
# 과학       0.0
# 국어       0.0
# 수학    8100.0
# 영어    8100.0
# dtype: float64
# 과학    0.0
# 국어    0.0
# 수학    1.0
# 영어    1.0
# dtype: float64

# %%
# 데이터 프레임 연산 (+,*,-,/)
# seaborn 에서 dataset 가져오기
import seaborn as sns

# %%
titanic=sns.load_dataset('titanic')
titanic.columns # age, fare 컬럼의 자료만 검색
df = titanic.loc[:,['age','fare']]
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# 5    man        True  NaN   Queenstown    no   True
# 6    man        True    E  Southampton    no   True
# 7  child       False  NaN  Southampton    no  False
# 8  woman       False  NaN  Southampton   yes  False
# 9  child       False  NaN    Cherbourg   yes  False

# %%
print(df.head(),'\n\n',(df+10).head()) #.head() -> 앞에서 부터 5개
# Out:
#     age     fare
# 0  22.0   7.2500
# 1  38.0  71.2833
# 2  26.0   7.9250
# 3  35.0  53.1000
# 4  35.0   8.0500
#
#      age     fare
# 0  32.0  17.2500
# 1  48.0  81.2833
# 2  36.0  17.9250
# 3  45.0  63.1000
# 4  45.0  18.0500

# %%
print(df.tail(),'\n\n',(df+10).tail()) #.tail() -> 뒤에서 부터 5개
# Out:
#       age   fare
# 886  27.0  13.00
# 887  19.0  30.00
# 888   NaN  23.45
# 889  26.0  30.00
# 890  32.0   7.75
#
#        age   fare
# 886  37.0  23.00
# 887  29.0  40.00
# 888   NaN  33.45
# 889  36.0  40.00
# 890  42.0  17.75

# %%
add_df = df.add(10, fill_value = 0)
add_df.tail()
# Out:
#       age   fare
# 886  37.0  23.00
# 887  29.0  40.00
# 888  10.0  33.45
# 889  36.0  40.00
# 890  42.0  17.75

# %%
# seaborn 에서 titanic 자료를 가져와서
import seaborn as sns
titanic=sns.load_dataset('titanic')
# 'class','sex','age','alive' 칼럼과 0행부터 100행까지만 자료가져오기
# df에 저장
df = titanic.loc[0:100,['class','sex','age','alive']]
df
# Out:
#       class     sex   age alive
# 0     Third    male  22.0    no
# 1     First  female  38.0   yes
# 2     Third  female  26.0   yes
# 3     First  female  35.0   yes
# 4     Third    male  35.0    no
# ..      ...     ...   ...   ...
# 96    First    male  71.0    no
# 97    First    male  23.0   yes
# 98   Second  female  34.0   yes
# 99   Second    male  34.0    no
# 100   Third  female  28.0    no
#
# [101 rows x 4 columns]

# %%
# 인덱스를 'class'로 지정하고 인덱스로 정렬
df.set_index('class', inplace = True)
print(df)
df.sort_index().head()
# Out:
#            sex   age alive
# class
# Third     male  22.0    no
# First   female  38.0   yes
# Third   female  26.0   yes
# First   female  35.0   yes
# Third     male  35.0    no
# ...        ...   ...   ...
# First     male  71.0    no
# First     male  23.0   yes
# Second  female  34.0   yes
# Second    male  34.0    no
# Third   female  28.0    no
#
# [101 rows x 3 columns]
#           sex   age alive
# class
# First  female   NaN   yes
# First    male   NaN    no
# First    male   NaN   yes
# First    male  65.0    no
# First  female  49.0   yes
